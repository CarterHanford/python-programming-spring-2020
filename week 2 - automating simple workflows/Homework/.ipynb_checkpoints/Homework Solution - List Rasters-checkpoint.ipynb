# %% [markdown]
# # Import ```arcpy```

# %%
import arcpy

# %% [markdown]
# # Define folder that has DEMs

# %%
dem_folder = r"C:\Users\greg6750\Documents\IPython Notebooks\intro-prog-for-gis-rs\Week 3\dems"

# %% [markdown]
# # Set Workspace

# %%
arcpy.env.workspace = dem_folder

# %% [markdown]
# # List Rasters

# %%
arcpy.ListDatasets()
# Out:
# ['af_dem_30s.tif',
#  'as_dem_30s.tif',
#  'au_dem_30s.tif',
#  'ca_dem_30s.tif',
#  'eu_dem_30s.tif',
#  'na_dem_30s.tif',
#  'sa_dem_30s.tif']

# %%
arcpy.ListRasters()
# Out:
# ['af_dem_30s.tif',
#  'as_dem_30s.tif',
#  'au_dem_30s.tif',
#  'ca_dem_30s.tif',
#  'eu_dem_30s.tif',
#  'na_dem_30s.tif',
#  'sa_dem_30s.tif']

# %%
len(arcpy.ListRasters())
# Out:
# 7

# %%
raster = arcpy.Raster('af_dem_30s.tif')

# %%
raster
# Out:
# af_dem_30s.tif

# %%
from IPython.display import display, clear_output

# %%
import time

for ras in arcpy.ListRasters():
    clear_output()
    display(arcpy.Raster(ras))
    time.sleep(2)
# Out:
# sa_dem_30s.tif

# %% [markdown]
# # An asside...

# %%
import arcgis 
from arcgis.features import GeoAccessor as ga

# %%
feature_class = r'C:\Users\greg6750\Documents\IPython Notebooks\intro-prog-for-gis-rs\Week 2\Missouri.gdb\Saint_Charles'
sdf = ga.from_featureclass(feature_class)

# %%
sdf
# Out:
#    OBJECTID  COUNTYNS  GEOID            NAMELSAD CLASSFP FUNCSTAT  \
# 0         1  00758546  29183  St. Charles County      H1        A
#
#           ALAND      AWATER     INTPTLAT     INTPTLON  \
# 0  1.451532e+09  83314211.0  +38.7811023  -90.6749153
#
#                                                SHAPE
# 0  {'rings': [[[-90.96100399999995, 38.8174580000...

# %%
sdf.loc[0, 'SHAPE']
# Out:
# {'rings': [[[-90.96100399999995, 38.817458000000016],
#    [-90.96098899999998, 38.817635000000024],
#    [-90.96096999999997, 38.81782000000001],
#    [-90.96093099999996, 38.818078000000014],
#    [-90.96092399999998, 38.818539000000015],
#    [-90.96095799999995, 38.818689000000006],
#    [-90.96096199999994, 38.818713],
#    [-90.96099799999996, 38.81875000000002],
#    [-90.96097799999995, 38.819388000000004],
#    [-90.96085999999997, 38.82148600000002],
#    [-90.96081599999997, 38.82236400000002],
#    [-90.96077199999996, 38.82324300000002],
#    [-90.96071699999999, 38.824342],
#    [-90.96066199999996, 38.82544100000001],
#    [-90.96065099999998, 38.825683000000026],
#    [-90.96063499999997, 38.826019],
#    [-90.96049299999999, 38.829025],
#    [-90.96027899999996, 38.83359100000001],
#    [-90.96003899999994, 38.83870900000002],
#    [-90.95997499999999, 38.840025000000026],
#    [-90.95995499999998, 38.840225000000004],
#    [-90.95993999999996, 38.840430000000026],
# ...

# %%
feature_class = r'C:\Users\greg6750\Documents\IPython Notebooks\intro-prog-for-gis-rs\Week 2\Missouri.gdb\County'
sdf = ga.from_featureclass(feature_class)

# %%
sdf.loc[111, 'SHAPE']
# Out:
# {'rings': [[[-90.32051499999994, 38.59415200000001],
#    [-90.32050399999997, 38.594177],
#    [-90.31964299999999, 38.59640700000003],
#    [-90.31940599999996, 38.59702200000001],
#    [-90.31903999999997, 38.597971],
#    [-90.31897299999997, 38.59814300000002],
#    [-90.31892599999998, 38.59826400000003],
#    [-90.31890499999997, 38.598319000000004],
#    [-90.31881699999997, 38.59855300000001],
#    [-90.31872999999996, 38.59871400000003],
#    [-90.31864799999994, 38.59892100000002],
#    [-90.31857999999994, 38.59909200000001],
#    [-90.31842999999998, 38.599470000000025],
#    [-90.31821199999996, 38.60001700000001],
#    [-90.31793099999999, 38.60073000000003],
#    [-90.31745899999999, 38.60190700000001],
#    [-90.31710599999997, 38.60281900000001],
#    [-90.31706499999996, 38.60292200000001],
#    [-90.31663899999995, 38.603999000000016],
#    [-90.31645699999996, 38.60446200000001],
#    [-90.31631899999996, 38.604814000000005],
# ...
